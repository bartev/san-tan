# %% [markdown]
# # Image tutorial

# %% [markdown]
# ## Startup commandsx

# %%
# %matplotlib inline

# %% [markdown]
# Imperitive style approach

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %% [markdown]
# ## Importing image data into Numpy arrays

# %% [markdown]
# * loading image data is supported by the `Pillow` library

# %%
img = mpimg.imread('stinkbug.png')

# %% [markdown]
# * 24-bit RGB PNG image
# * 8 bits each for R, G, B
# * RGBA allows for transparency too
# * matplotlib rescaled each channel to a float btw 0.0 and 1.0
# * each inner list is a pixel

# %%
img
# Out:
# array([[[ 0.40784314,  0.40784314,  0.40784314],
#         [ 0.40784314,  0.40784314,  0.40784314],
#         [ 0.40784314,  0.40784314,  0.40784314],
#         ...,
#         [ 0.42745098,  0.42745098,  0.42745098],
#         [ 0.42745098,  0.42745098,  0.42745098],
#         [ 0.42745098,  0.42745098,  0.42745098]],
#
#        [[ 0.41176471,  0.41176471,  0.41176471],
#         [ 0.41176471,  0.41176471,  0.41176471],
#         [ 0.41176471,  0.41176471,  0.41176471],
#         ...,
#         [ 0.42745098,  0.42745098,  0.42745098],
#         [ 0.42745098,  0.42745098,  0.42745098],
#         [ 0.42745098,  0.42745098,  0.42745098]],
#
#        [[ 0.41960785,  0.41960785,  0.41960785],
#         [ 0.41568628,  0.41568628,  0.41568628],
#         [ 0.41568628,  0.41568628,  0.41568628],
#         ...,
#         [ 0.43137255,  0.43137255,  0.43137255],
#         [ 0.43137255,  0.43137255,  0.43137255],
#         [ 0.43137255,  0.43137255,  0.43137255]],
#
#        ...,
# ...

# %% [markdown]
# ## Plotting numpy arrays as images

# %%
imgplot = plt.imshow(img)

# %% [markdown]
# ### Apply pseudocolor schemes to image plots

# %% [markdown]
# only relevant to single-channel, grayscale luminosity images

# %%
img.shape
# Out:
# (375, 500, 3)

# %%
lum_img = img[:, :250, 0]
plt.imshow(lum_img)

# %%
lum_img = img[:, :, 0]
plt.imshow(lum_img, cmap = 'hot')

# %%
imgplot = plt.imshow(lum_img)
imgplot.set_cmap('spectral')

# %% [markdown]
# # Note:
# When using inline backend, you
# can't make changes to plots that have already
# been rendered.
# All commands must be in the same IPython cell

# %% [markdown]
# ### Color scale reference

# %%
imgplot = plt.imshow(lum_img)
plt.colorbar()

# %% [markdown]
# ### Examine a specific data range

# %% [markdown]
# Create a historgram of image data

# %%
plt.hist(lum_img.ravel(), bins = 256, range = (0.0, 1.0), 
         fc = 'k',
         ec = 'r');

# %% [markdown]
# Adjust upper limit (clip)
# * `set_clim()`

# %%
fig = plt.figure()
img = mpimg.imread('stinkbug.png')
lum_img = img[:, :, 0]

a = fig.add_subplot(1,2,1)
imgplot = plt.imshow(lum_img)
a.set_title('Before')
plt.colorbar(ticks = [0.1,0.3,0.5,0.7], orientation = 'horizontal')

a = fig.add_subplot(1,2,2)
imgplot = plt.imshow(lum_img)
imgplot.set_clim(0.0, 0.7)
a.set_title('After')
plt.colorbar(ticks = [0.1, 0.3, 0.5, 0.7], orientation = 'horizontal')
