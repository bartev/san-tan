# %% [markdown]
# # Matplotlib tutorial

# %%
import matplotlib as mpl

# %% [markdown]
# ## Dynamic rc setting

# %%
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['lines.color'] = 'r'

# %% [markdown]
# ### Reset to defaults

# %%
matplotlib.rcdefaults()

# %% [markdown]
# ### Set muliple settings in a single group at once

# %%
mpl.rc('lines', linewidth = 2, color = 'r')

# %%
dir(matplotlib.rcsetup)
# Out:
# ['Cycler',
#  'ValidateInStrings',
#  'ValidateInterval',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__name__',
#  '__package__',
#  '_listify_validator',
#  '_prop_aliases',
#  '_prop_validators',
#  '_seq_err_msg',
#  '_str_err_msg',
#  '_validate_standard_backends',
#  'absolute_import',
#  'all_backends',
#  'ccycler',
#  'cycler',
#  'defaultParams',
#  'deprecate_axes_colorcycle',
#  'deprecate_savefig_extension',
#  'deprecate_svg_embed_char_paths',
#  'division',
#  'interactive_bk',
#  'is_color_like',
#  'non_interactive_bk',
#  'operator',
#  'os',
#  'parse_fontconfig_pattern',
#  'print_function',
#  'reduce',
#  'six',
#  'unicode_literals',
#  'update_savefig_format',
#  'validate_any',
#  'validate_anylist',
#  'validate_aspect',
#  'validate_axis_locator',
#  'validate_backend',
#  'validate_bbox',
#  'validate_bool',
#  'validate_bool_maybe_none',
#  'validate_capstyle',
#  'validate_capstylelist',
#  'validate_color',
#  'validate_color_or_inherit',
# ...

# %% [markdown]
# ### Where is the current `matplotlibrc` file?

# %% [markdown]
# See the default file for variables you can set

# %%
matplotlib.matplotlib_fname()
# Out:
# u'/Users/bartev/.virtualenvs/aost/lib/python2.7/site-packages/matplotlib/mpl-data/matplotlibrc'

# %% [markdown]
# ## Run a demo

# %%
from IPython.lib.demo import Demo

# %% [markdown]
# Create a demo object

# %%
mydemo = Demo('demo-1.py')

# %% [markdown]
# mydemo()

# %% [markdown]
# ## Using matplotlib in a python shell

# %% [markdown]
# ### IPython to the rescue

# %%
import numpy as np
import matplotlib as mpl

x = np.random.randn(1000)
mpl.hist(x, 100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-62c60bf779e9> in <module>()
#       3
#       4 x = np.random.randn(1000)
# ----> 5 mpl.hist(x, 100)
#
# AttributeError: 'module' object has no attribute 'hist'

# %%
import pylab as py

# %%
py.plot([1, 2, 3])
py.xlabel('hi mom')

# %%
import pylab as py

# %%
py.isinteractive()
# Out:
# False

# %%
py.ioff()
py.isinteractive()
# Out:
# False

# %%
py.ion()
py.isinteractive()
# Out:
# True

# %%
py.draw()

# %% [markdown]
# Create a big expensive figure

# %%
py.ioff()
py.title('now how much would you pay?')
# py.xticklabels(fontsize = 20, color = 'green')
py.draw()
py.savefig('alldone', dpi = 300)
py.close()
py.ion() # turn updating back on 
py.plot(np.random.rand(20), mfc = 'r',
     ms = 40, mew = 4, ls = '--', lw = 3)

# %% [markdown]
# Saved blank frame to 'alldone.png'

# %% [markdown]
# ## Pyplot tutorial

# %% [markdown]
# `matplotlib.pyplot`
#   * command style functions that make matplotlib work like MATLAB
#   * each functions makes some change to a figure

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %% [markdown]
# #### plot x vs y

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# plot with red circles
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro--')
plt.axis([0, 6, 0, 20])
plt.show()

# %%
plt.plot?

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# evenly sampled time at 400ms intervals
t = np.arange(0., 5., 0.4)

# red dashes, blue squares, green triangles
plt.plot(t, t, 'r--',     # dashed line
         t, t**2, 'bs:',  # dotted
         t, t**3, 'g^-.') # dash-dot
plt.show()

# %% [markdown]
# ### Controlling line properties

# %% [markdown]
# * use keyword args
# * see `matplotlib.lines.Line2D`

# %%
matplotlib.lines.Line2D?

# %%
x = [1, 2, 3, 4]
y = [z ** 2 for z in x]

# %%
plt.plot(x, y, linewidth = 2.0)

# %% [markdown]
# * use the setter methods of a `Line2D` instance
# * `plot` returns a list of `Line2D` objects

# %%
line, = plt.plot(x, y, '-')
line.set_antialiased(False)

# %% [markdown]
# * use the `setp()` command to set multiple properties

# %%
x1 = np.arange(5) + 1
y1 = x1 ** 2
x2 = x1 + 0.5
y2 = x1 ** 3

# %%
import pandas as pd
from numpy.random import randn

# %%
lines = plt.plot(x1, y1, x2, y2)
plt.setp(lines, color = 'r', linewidth = 2.0)
# Out:
# [None, None, None, None]

# %%
lines

# %% [markdown]
# Or

# %%
lines = plt.plot(x1, y1, x2, y2)
plt.setp(lines, 'color', 'r', 'linewidth' , 2.0)
# Out:
# [None, None, None, None]

# %% [markdown]
# To get settable properties, call `setp()` with a line as arg

# %%
plt.setp(lines)
# Out:
#   agg_filter: unknown
#   alpha: float (0.0 transparent through 1.0 opaque)
#   animated: [True | False]
#   antialiased or aa: [True | False]
#   axes: an :class:`~matplotlib.axes.Axes` instance
#   clip_box: a :class:`matplotlib.transforms.Bbox` instance
#   clip_on: [True | False]
#   clip_path: [ (:class:`~matplotlib.path.Path`,         :class:`~matplotlib.transforms.Transform`) |         :class:`~matplotlib.patches.Patch` | None ]
#   color or c: any matplotlib color
#   contains: a callable function
#   dash_capstyle: ['butt' | 'round' | 'projecting']
#   dash_joinstyle: ['miter' | 'round' | 'bevel']
#   dashes: sequence of on/off ink in points
#   drawstyle: ['default' | 'steps' | 'steps-pre' | 'steps-mid' |                   'steps-post']
#   figure: a :class:`matplotlib.figure.Figure` instance
#   fillstyle: ['full' | 'left' | 'right' | 'bottom' | 'top' | 'none']
#   gid: an id string
#   label: string or anything printable with '%s' conversion.
# ...

# %% [markdown]
# ### Working with multiple figures and axes

# %% [markdown]
# * `pyplot` has the concept of the **current figure** and **current axes**
# * plotting commands apply to current axes
# * `gca()` returns the current axes (get current axes?)
# * `gcf()` returns the current figure

# %% [markdown]
# #### Example script - create 2 subplots

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(t):
    return np.exp(-t) * np.cos(2 * np.pi * t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

# %%
plt.figure(1)
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2 * np.pi * t2), 'r--')
plt.show()

# %% [markdown]
# #### `subplot(numrows, numcols, fignum)`

# %% [markdown]
# Notes:
# * `plt.figure(1)` is optional - will be created by default
# * `subplot(111)` will be created by default if I don't specify axes
# * `subplot()` specifies `numrows`, `numcols`, `fignum`
#   * `fignum` ranges between 1 and `numrows * numcols`
# * if `numrows * numcols` < 10, then commas are optional
#   * `subplot(2, 1, 2)` is the same as `subplot(212)`

# %% [markdown]
# #### Create multiple figures

# %% [markdown]
# * call `figure()` with an increasing figure number

# %%
import matplotlib.pyplot as plt
plt.figure(1)    # first figure
plt.subplot(211) # first subplot in 1st figure
plt.plot([1, 2, 3])
plt.subplot(212)
plt.plot([4, 5, 6])

plt.figure(2)    # second figure
plt.plot([4, 5, 6])

plt.figure(1)    # figure 1 current, subplot(212) still current
plt.subplot(211) # make subplot(211) in fig1 current
plt.title('Easy as 1, 2, 3')  # subplot 211 title

# %% [markdown]
# #### Clear figures and axes

# %% [markdown]
# * `clf()` clear figure
# * `cla()` clear axes

# %% [markdown]
# ### Working with text

# %% [markdown]
# * `text()` - add text in arbitrary location
# * `xlabel()`, `ylabel()`
# * `title()`

# %%
import numpy as np
import matplotlib.pyplot as plt

mu, sigma = 100, 15
x = mu + sigma * np.random.randn(1000)

# historgram of the data
n, bins, patches = plt.hist(x,
                            50,
                            normed = 1,
                            facecolor = 'g',
                            alpha = 0.75)
plt.xlabel('Smarts', fontsize = 18, color = 'red')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(50, 0.022, r'$\mu = 100,\ \sigma = 15$', 
         fontsize = 14, color = 'blue')
plt.axis ([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %% [markdown]
# ### Using mathematical expressions in text (TeX)

# %% [markdown]
# * can write a TeX expression surrounded by dollar signs
#   * `plt.title(r'$\sigma_i=15$')`
# * `r` indicates a `raw` string
#   * don't treat backslashes as python escapes

# %% [markdown]
# ### Annotate text

# %% [markdown]
# * `annotate()` methods
# * location being annotated represented by argument `xy`
# * location of the text `xytext`
# * `(x, y)` tuples

# %%
import numpy as np
import matplotlib.pyplot as plt

ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2 * np.pi * t)
line = plt.plot(t, s, lw = 2)

plt.ylim(-2, 2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2 * np.pi * t)
line = plt.plot(t, s, lw = 2)

plt.annotate('local max',
             xy = (2, 1),
             xytext = (3, 1.5),
             arrowprops = dict(facecolor = 'black',
                               shrink = 0.05),
             )

plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# ### Logarithmic and other nonlinear axis

# %% [markdown]
# * Changing scale of axis
#   * `plt.xscale('log')`

# %% [markdown]
# Example - 4 plots, same data, different scales

# %%
import numpy as np
import matplotlib.pyplot as plt

# make up data
y = np.random.normal(loc = 0.5, scale = 0.4, size = 1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# %%
# plot with various axex and scales
plt.figure(1)

# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)

# Logarithmic
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)

# symmetric log
plt.subplot(223)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthres = 0.05)
plt.title('smlog')
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)

plt.show()

# %% [markdown]
# ## Customize plots with style sheets

# %% [markdown]
# * `style` package
# * allows switching styles with same params as `matplotlibrc` file
# * some predefined styles:
#   * `ggplot`
# * see all available styles
# ```
# print plt.style.available
# ```
# * use a style
# ```
# import matplotlib.pyplot as plt
# plt.style.use('ggplot')
# ```

# %%
plt.style.available
# Out:
# [u'seaborn-darkgrid',
#  u'seaborn-notebook',
#  u'classic',
#  u'seaborn-ticks',
#  u'grayscale',
#  u'bmh',
#  u'seaborn-talk',
#  u'dark_background',
#  u'ggplot',
#  u'fivethirtyeight',
#  u'seaborn-colorblind',
#  u'seaborn-deep',
#  u'seaborn-whitegrid',
#  u'seaborn-bright',
#  u'seaborn-poster',
#  u'seaborn-muted',
#  u'seaborn-paper',
#  u'seaborn-white',
#  u'seaborn-pastel',
#  u'seaborn-dark',
#  u'seaborn-dark-palette']

# %% [markdown]
# ### Defining your own style

# %% [markdown]
# ### Composing styles

# %% [markdown]
# Style sheets can be composed together.
#
# Can have a style sheet customizing colors, and another
# for setting presentation sizes
#
# ```
# matplotlib.pyplot as plt
# plt.style.use(['dark_background', 'presentation'])
# ```

# %% [markdown]
# ### Temporary styling

# %%
with plt.style.context(('dark_background')):
    plt.plot(np.sin(np.linspace(0, 2 * np.pi)), 'r-o')

# %% [markdown]
# ### Basic text commands

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
fig.suptitle ('bold figure suptitle', fontsize = 14, fontweight = 'bold')

ax = fig.add_subplot(111)
fig.subplots_adjust(top = 0.85)
ax.set_title('axes title')
ax.set_xlabel('xlabel')
ax.set_ylabel('ylabel')

ax.text(3, 8, 'boxed italics text in data coords', 
        style = 'italic',
        bbox = {'facecolor': 'red', 
                'alpha' : 0.25,
                'pad' : 10})

ax.text(2, 6, r'an equation $E = mc^2$', fontsize = 15)

ax.text(3, 2, u'unicode: Institut f\374r Festk\366rperphysik')

ax.text(0.95, 0.01, 'colored text in axes coords',
        verticalalignment = 'bottom',
        horizontalalignment = 'right',
        transform= ax.transAxes,
        color = 'green',
        fontsize = 15)

ax.plot([2], [1], 'o')
ax.annotate('annotate', 
            xy = (2, 1), 
            xytext = (3, 4),
            arrowprops = dict(facecolor = 'black', 
                              shrink = 0.05))

ax.axis([0, 10, 0, 10])

plt.show()

# %% [markdown]
# ### Text properties and layout

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
# build a rectangle in axes coords
left, width = 0.15, 0.7
bottom, height = 0.15, 0.7
right = left + width
top = bottom + height
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
# axes coords are 0, 0 is bottom left, 1, 1 is upper right
p = patches.Rectangle(
    (left, bottom), width, height,
    fill = False,
    transform = ax.transAxes,
    clip_on = False
)

ax.add_patch(p)

ax.text(left, bottom, 'left top', 
        horizontalalignment = 'left',
        verticalalignment = 'top', 
        transform = ax.transAxes)

ax.text(left, bottom, 'left bottom', 
        horizontalalignment = 'left', 
        verticalalignment = 'bottom',
        transform = ax.transAxes)

ax.text(right, top, 'right bottom', 
        horizontalalignment = 'right',
        verticalalignment = 'bottom', 
        transform = ax.transAxes)

ax.text(right, top, 'right top', 
        horizontalalignment = 'right',
        verticalalignment = 'top', transform = ax.transAxes)

ax.text(right, bottom, 'center top', 
        horizontalalignment = 'center',
        verticalalignment = 'top', 
        transform = ax.transAxes)

ax.text(left, 0.5 * (bottom + top), 'right center', 
        horizontalalignment = 'right',
        verticalalignment = 'center', 
        rotation = 'vertical', 
        transform = ax.transAxes)

ax.text(left, 0.5 * (bottom + top), 'left center', 
        horizontalalignment = 'left',
        verticalalignment = 'center', 
        rotation = 'vertical', 
        transform = ax.transAxes)

ax.text(0.5 * (left + right), 0.5 * (bottom + top), 'middle', 
        horizontalalignment = 'center',
        verticalalignment = 'center',
        fontsize = 20, 
        color = 'red', 
        transform = ax.transAxes)

ax.text(right, 0.5 * (bottom + top), 'centered', 
        horizontalalignment = 'center',
        verticalalignment = 'center', 
        rotation = 'vertical', 
        transform = ax.transAxes)

ax.text(left, top, 'rotated\nwith newlines', 
        horizontalalignment = 'center',
        verticalalignment = 'center', 
        rotation = 45, 
        transform = ax.transAxes)
# ax.set_axis_off()
plt.show()

# %% [markdown]
# ### Writing mathematical expressions

# %% [markdown]
# Example

# %%
import numpy as np
import matplotlib.pyplot as plt 
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2 * np.pi * t)

plt.plot(t, s)
plt.title(r'$\alpha_i > \beta_i$', fontsize = 20)
plt.text(1, -0.6, r'$\sum_{i=0}^\infty x_i$', fontsize = 20) 
plt.text(0.6, 0.6, r'$\mathcal{A}\mathrm{sin}(2 \omega t)$',
         fontsize = 20) 
plt.xlabel('time (s)')
plt.ylabel('volts (mV)') 
plt.show()
